# %% [markdown]
# # I. INTRODUCTION TO FOLIUM

# %% [markdown]
# Folium is a powerful data visualization library in
# Python that was built primarily to help people visualize geospatial data. With
# Folium, you can create a map of any location in the world as long as you
# know its latitude and longitude values. You can also create a map and
# superimpose markers as well as clusters of markers on top of the map for cool
# and very interesting visualizations. You can also create maps of different styles
# such as street level map, stamen map and, a couple others which we will look
# into in just a moment

# %% [markdown]
# Creating a world map with Folium is pretty
# straightforward.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we pass in the latitude and the longitude values of
# Canada using the location parameter and with Folium you can set the initial zoom
# level using the zoom start parameter.
# ![image.png](attachment:image.png)

# %% [markdown]
#  This
# style is great for visualizing and exploring river meanders
# and coastal zones.
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's create a map of
# Canada in stamen terrain. This style is great for visualizing hill shading and
# natural vegetation colors.
# ![image.png](attachment:image.png)

# %% [markdown]
# # II. Maps with Markers

# %% [markdown]
# ### Add a markers
# - Let's see how we can add a circular mark to the centre of Ontario. To do that, we need to create what is called a feature group.
# ![image.png](attachment:image.png)

# %% [markdown]
# - To do that, we need to create what is called a feature group.(create a feature group named ontario)
# - Now when a feature group is created, it is empty and that means what's next is to start creating what is called children and adding them to the feature group.(let's create a child in the form of a red circular mark located at the centre of the Ontario province)
# - Once we're done adding children to the feature group we add the featured group to the map.

# %% [markdown]
# # III. Choropleth maps

# %% [markdown]
# - A choropleth map is a thematic map in which areas are shaded or patterned in proportion to the measurement of the statistical variable being displayed on the map, such as population density or per capita income. The higher the measurement the darker the color.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - Folium requires a Geo JSON file that includes geospatial data of the region. For a choropleth map of the world, we would need a Geo JSON file that lists each country along with any geospatial data to define its borders and boundaries.

# %% [markdown]
# ![image.png](attachment:image.png)
# - Create a world map but this time let's use the mapbox bright tiles set. The result is a nice world map displaying the name of every country.
# - Now to convert this map into a choropleth map, we first define a variable that points to our Geo JSON file.
# - Then we apply the choropleth function to our world map and we tell it to use the columns "Country" and "Total" in our df_canada dataframe, and to use the country names to look up the geospatial information about each country in the Geo JSON file.
