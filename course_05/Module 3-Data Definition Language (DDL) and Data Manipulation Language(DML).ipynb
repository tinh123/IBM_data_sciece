# %% [markdown]
# # I. Create table statement

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # II. Insert Statement

# %% [markdown]
# - To insert data into a table, we use the INSERT statement.
# - The insert statement is used to add new rows to a table.
# - The INSERT statement is one of the Data Manipulation Language statements.
# - Data Manipulation Language statements, or DML statements, are used to read and modify data.
# ![image.png](attachment:image.png)
# Multiple rows can be inserted by specifying each row in the Values clause.In the Values clause, each row is separated by a comma.

# %% [markdown]
# # III. Select statement

# %% [markdown]
# ![image.png](attachment:image.png)
# The SELECT statement is a Data Manipulation Language statement.
# Data Manipulation Language statements, or DML statements, are used to read and modify
# data.

# %% [markdown]
# # IV. Update statement

# %% [markdown]
# - The UPDATE statement is one of the Data Manipulation Language or DML statements. DML statements are used to read and modify data.

# %% [markdown]
# ![image.png](attachment:image.png)
# The SELECT statement is called a query, and the output we get from executing this query
# is called a Result Set or a Result Table.

# %% [markdown]
# # V. Delete statement

# %% [markdown]
# ![image.png](attachment:image.png)
# The DELETE statement is one of the Data Manipulation Language statements used to read and modify data.
