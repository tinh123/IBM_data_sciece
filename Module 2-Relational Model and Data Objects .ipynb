# %% [markdown]
#  # I. Relational Model Constraints Introduction

# %% [markdown]
# The Entity-Relationship Diagram represents the Relational Data Model for the Author entity
# and Book entity as part of a simplified library database model.

# %% [markdown]
# ### A Primary Key of a relational table uniquely identifies each row in a table.

# %% [markdown]
# ### A Foreign Key is a set of columns referring to a primary key of another table.
# - These entities are part of the relationship set between the entities above them.
# All of the entities have a one-to-many relationship established between them.

# %% [markdown]
# ### A table containing a primary key that is related to at least one foreign key is called a Parent table.

# %% [markdown]
# ### A table containing one or more foreign keys is called a dependent table. It might also be referred to as a child table

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # II. Relational Model Constraints Advanced

# %% [markdown]
# ### 1. Model constraints

# %% [markdown]
# - In a relational data model, data integrity can be achieved using integrity rules or constraints.
# - The following six constraints are defined in a relational database model:
#     - Entity Integrity constraint
#     - Referential Integrity constraint
#     - Semantic Integrity constraint
#     - Domain constraint
#     - Null constraint
#     - Check constraint.

# %% [markdown]
# ### a.  Entity Integrity Constraint
# - To identify each tuple in a relation, the relation must have a primary key.The primary key is a unique value that identifies each tuple (or row) in a table.
# ![image.png](attachment:image.png)
# This constraint prevents duplicate values in a table.
# To implement these constraints, indexes are used.
# The Entity Integrity Constraint states that no attribute participating in the primary
# key of a relation is allowed to accept NULL values.
# The value NULL indicates that the value is unknown.
# In the Entity Integrity Constraint, the primary key cannot have an unknown value.

# %% [markdown]
#   ### b. Referential integrity constraint
#   - Referential integrity constraint defines relationships between tables and ensures that these relationships remain valid.
#   - The validity of the data is enforced using a combination of Primary Keys and Foreign Keys.
# As mentioned previously, for a book to exist it has to be written by at least one author.

# %% [markdown]
# ### c. Semantic Integrity Constraint
# - The Semantic Integrity Constraint refers to the correctness of the meaning of the data.
# - The Semantic Integrity Constraint is related to the correctness of the data.

# %% [markdown]
# ### d. Domain Constraint
# - A Domain Constraint specifies the permissible values for a given attribute.

# %% [markdown]
# ### e. The NULL constraint specifies that attribute values cannot be null.

# %% [markdown]
# ### f. Check contraint
# - The CHECK constraint enforces domain integrity by limiting the values that are accepted by an attribute.
# - The CHECK constraint would enforce the domain integrity by limiting the values
